# %%
import pandas as pd
import numpy as np

# %%
sockets = ['LGA 1200', 'LGA 1700', 'AM4', 'AM5', 'LGA 2066', 'LGA 1151v2']

# %%
df_cpu = pd.read_csv('sourceData/CPU_benchmark_v4.csv')
df_cpu
# Out:
#                                 cpuName    price  cpuMark  cpuValue
# 0     AMD Ryzen Threadripper PRO 5995WX      NaN   108822       NaN  \
# 1                         AMD EPYC 7763  7299.99    88338     12.10
# 2                         AMD EPYC 7J13      NaN    86006       NaN
# 3                         AMD EPYC 7713  7060.00    85861     12.16
# 4     AMD Ryzen Threadripper PRO 3995WX  6807.98    83971     12.33
# ...                                 ...      ...      ...       ...
# 3820            Intel Pentium 4 1.60GHz      NaN       84       NaN
# 3821            Intel Pentium 4 1400MHz      NaN       83       NaN
# 3822            Intel Pentium 4 1500MHz      NaN       81       NaN
# 3823                   VIA Eden 1000MHz      NaN       80       NaN
# 3824            Intel Pentium 4 1300MHz      NaN       77       NaN
#
#       threadMark  threadValue    TDP powerPerf  cores  testDate    socket
# 0           3330          NaN  280.0    388.65     64      2022     sWRX8  \
# ...

# %%
df_cpu = df_cpu[df_cpu['socket'] != 'unknown']
df_cpu.shape
# Out:
# (3037, 12)

# %%
df_cpu = df_cpu[~np.isnan(df_cpu['price'])]
df_cpu.shape
# Out:
# (1921, 12)

# %%
df_cpu = df_cpu.drop(columns=['testDate', 'powerPerf'])

# %%
df_cpu
# Out:
#                                 cpuName    price  cpuMark  cpuValue
# 1                         AMD EPYC 7763  7299.99    88338     12.10  \
# 3                         AMD EPYC 7713  7060.00    85861     12.16
# 4     AMD Ryzen Threadripper PRO 3995WX  6807.98    83971     12.33
# 5          AMD Ryzen Threadripper 3990X  8399.69    81568      9.71
# 8                         AMD EPYC 7643  5424.99    76455     14.09
# ...                                 ...      ...      ...       ...
# 3697                AMD Athlon XP 2000+    58.99      195      3.31
# 3711                  AMD Sempron 2200+    39.95      184      4.60
# 3725          Intel Atom D410 @ 1.66GHz   635.99      177      0.28
# 3727                AMD Athlon XP 1700+    51.25      176      3.44
# 3747         Intel Atom E3815 @ 1.46GHz   135.00      159      1.17
#
#       threadMark  threadValue    TDP  cores          socket category
# 1           2635         0.36  280.0     64             SP3   Server
# ...

# %%
for price in range(len(df_cpu['price'].values)):
    df_cpu['price'].values[price] = round(df_cpu['price'].values[price] * 80, 2)

# %%
import regex as re

# %%
for socket in range(len(df_cpu['socket'].values)):
    if re.match(r"^FC", df_cpu['socket'].values[socket]):
        reg = re.match(r"^FC", df_cpu['socket'].values[socket])
        df_cpu['socket'].values[socket] = df_cpu['socket'].values[socket][reg.end():]
    reg2 = re.match(r"[L|B]GA", df_cpu['socket'].values[socket])
    if reg2:
        df_cpu['socket'].values[socket] = df_cpu['socket'].values[socket][0:reg.end()+1] + ' ' + df_cpu['socket'].values[socket][reg.end()+1:]
    if df_cpu['socket'].values[socket] not in sockets:
        df_cpu['socket'].values[socket] = 'unknown'

# %%
df_cpu = df_cpu[df_cpu['socket'] != 'unknown']
df_cpu.shape
# Out:
# (214, 10)

# %%
df_cpu.head(20)
# Out:
#                              cpuName     price  cpuMark  cpuValue  threadMark
# 39                 AMD Ryzen 9 5950X   51979.2    46195     71.10        3498  \
# 53             Intel Core i9-12900KF   45838.4    41163     71.84        4217
# 54              Intel Core i9-12900K   47996.0    41077     68.47        4209
# 63                 AMD Ryzen 9 5900X   31442.4    39457    100.39        3494
# 64                 AMD Ryzen 9 3950X   52000.0    39157     60.24        2738
# 67               Intel Core i9-12900   40720.0    38281     75.21        4162
# 75              Intel Core i9-12900F   42399.2    35726     67.41        4045
# 78              Intel Core i9-12900T   39120.0    34999     71.57        4032
# 80              Intel Core i7-12700K   32720.0    34125     83.44        4047
# 81             Intel Core i7-12700KF   28079.2    34110     97.18        4054
# 85   Intel Core i9-10980XE @ 3.00GHz   79999.2    33408     33.41        2667
# ...

# %%
df_cpu.to_csv('data/CPU.csv')
